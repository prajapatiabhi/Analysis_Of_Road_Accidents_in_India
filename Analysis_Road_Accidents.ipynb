# %% [markdown]
# <a href="https://colab.research.google.com/github/prajapatiabhi/Analysis_Of_Road_Accidents_in_India/blob/Abhishek/Analysis_Road_Accidents.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **ANALYSIS OF ROAD ACCIDENTS IN INDIA**

# %% [markdown]
# 1.   ABHISHEK KUMAR PRAJAPATI (AB-1202)
# 2.   UJJWAL (AB-1257)
# 3.   SHIVAM SAINI (AB-1237)

# %% [markdown]
# # **DATA SOURCE:** https://data.gov.in/dataset-group-name/road-accidents

# %% [markdown]
# IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #**DF 1 - This data set shows the number of accidents happening per state from the year 2003 to 2016.**

# %%
df1 = pd.read_excel('/content/accidents03-16.xls')
df1.head()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
#           States/Uts    2003    2004    2005  ...     2013  2014  2015  2016
# 0     Andhra Pradesh  8616.0  9343.0  9126.0  ...  13175.0  7277  7524  7851
# 1  Arunachal Pradesh    65.0    79.0    63.0  ...    120.0    92   117   103
# 2              Assam  1120.0  1177.0  1420.0  ...   2162.0  2169  2122  2445
# 3              Bihar  2138.0  1579.0  1462.0  ...   4612.0  4505  4771  4425
# 4       Chhattisgarh  1788.0  1892.0  2049.0  ...   3059.0  3570  3710  3527
#
# [5 rows x 15 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   States/Uts  37 non-null     object
#  1   2003        36 non-null     float64
#  2   2004        36 non-null     float64
#  3   2005        36 non-null     float64
#  4   2006        36 non-null     float64
#  5   2007        36 non-null     float64
#  6   2008        36 non-null     float64
#  7   2009        36 non-null     float64
#  8   2010        36 non-null     float64
#  9   2011        36 non-null     float64
#  10  2012        35 non-null     float64
#  11  2013        36 non-null     float64
#  12  2014        37 non-null     int64
#  13  2015        37 non-null     int64
#  14  2016        37 non-null     int64
# dtypes: float64(11), int64(3), object(1)
# memory usage: 4.5+ KB

# %%
df1['States/Uts']
# Out:
# 0                Andhra Pradesh
# 1             Arunachal Pradesh
# 2                         Assam
# 3                         Bihar
# 4                  Chhattisgarh
# 5                           Goa
# 6                       Gujarat
# 7                       Haryana
# 8              Himachal Pradesh
# 9               Jammu & Kashmir
# 10                    Jharkhand
# 11                    Karnataka
# 12                       Kerala
# 13               Madhya Pradesh
# 14                  Maharashtra
# 15                      Manipur
# 16                    Meghalaya
# 17                      Mizoram
# 18                     Nagaland
# 19                       Odisha
# 20                       Punjab
# 21                    Rajasthan
# 22                       Sikkim
# 23                   Tamil Nadu
# 24                    Telangana
# 25                      Tripura
# 26                  Uttarakhand
# 27                Uttar Pradesh
# 28                  West Bengal
# ...

# %%
df1_analysis = pd.DataFrame(columns = ['Year','Accidents'])

# %%
df1_analysis['Year'] = df1.columns

# %%
df1_analysis.set_index('Year', inplace = True)

# %%
df1_analysis['Accidents'] = df1.iloc[36]

# %%
df1_analysis.drop('States/Uts',axis = 0, inplace = True)

# %%
df1_analysis
# Out:
#      Accidents
# Year
# 2003     73589
# 2004     79357
# 2005     83491
# 2006     93917
# 2007    101161
# 2008    106591
# 2009    110993
# 2010    119558
# 2011    121618
# 2012    123093
# 2013    122589
# 2014    125828
# 2015    131726
# 2016    136071

# %%
plt.figure(figsize = (20,10))
plt.rcParams.update({'font.size' : 18})

df1_analysis.iloc[1:].plot(figsize = (20,10), legend =  True)
plt.xlabel("Year")
plt.ylabel("No of Accidents")
plt.title("No. of Accidents/Year")
plt.show()

# %% [markdown]
# # DF3 -
# This dataset is about **Number of accidents** per state, accidents sharing multiple states and TOTAL number of accidents overall
# per year per state.

# %%
df3 = pd.read_csv('/content/roadAccStats13-16.csv')

# %%
df3
# Out:
#    SI. No.  ... Total Number of Road Accidents per 10,000 Km of Roads - 2015
# 0        1  ...                                             1355.0
# 1        2  ...                                              112.0
# 2        3  ...                                              213.1
# 3        4  ...                                              463.8
# 4        5  ...                                             1481.1
# 5        6  ...                                             2966.4
# 6        7  ...                                             1271.8
# 7        8  ...                                             2414.1
# 8        9  ...                                              541.4
# 9       10  ...                                             1492.7
# 10      11  ...                                             1208.8
# 11      12  ...                                             1367.6
# 12      13  ...                                             2002.2
# ...

# %%
df3.drop(36, axis = 0, inplace = True)

# %%
df3.shape
# Out:
# (36, 20)

# %%
type(df3['SI. No.'][0])
# Out:
# str

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36 entries, 0 to 35
# Data columns (total 20 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   SI. No.                                                       36 non-null     object
#  1   States/UTs                                                    36 non-null     object
#  2   State/UT-Wise Total Number of Road Accidents during - 2013    35 non-null     float64
#  3   State/UT-Wise Total Number of Road Accidents during - 2014    36 non-null     int64
#  4   State/UT-Wise Total Number of Road Accidents during - 2015    36 non-null     int64
#  5   State/UT-Wise Total Number of Road Accidents during - 2016    36 non-null     int64
#  6   Share of States/UTs in Total Number of Road Accidents - 2013  36 non-null     float64
# ...

# %%
df3['States/UTs'].value_counts()
# Out:
# Meghalaya                    1
# Dadra & Nagar Haveli         1
# Puducherry                   1
# Gujarat                      1
# Punjab                       1
# Bihar                        1
# Daman & Diu                  1
# Madhya Pradesh               1
# Andhra Pradesh               1
# Kerala                       1
# Goa                          1
# Arunachal Pradesh            1
# Himachal Pradesh             1
# West Bengal                  1
# Tripura                      1
# Manipur                      1
# Tamil Nadu                   1
# Uttarakhand                  1
# Nagaland                     1
# Sikkim                       1
# Karnataka                    1
# Maharashtra                  1
# Jammu & Kashmir              1
# Haryana                      1
# Mizoram                      1
# Odisha                       1
# Assam                        1
# Chhattisgarh                 1
# Delhi                        1
# Telangana                    1
# ...

# %% [markdown]
# # **Calculating the mean of State wise Total number of Road Accidents.**

# %%
mean13 = np.mean(df3['State/UT-Wise Total Number of Road Accidents during - 2013'])
print("Mean of accidents happened in all states in year 2013: {}".format(mean13))
# Out:
# Mean of accidents happened in all states in year 2013: 13899.314285714287

# %%
mean14 = np.mean(df3['State/UT-Wise Total Number of Road Accidents during - 2014'])
print("Mean of accidents happened in all states in year 2014 : {}".format(mean14))
# Out:
# Mean of accidents happened in all states in year 2014 : 13594.444444444445

# %%
mean15 = np.mean(df3['State/UT-Wise Total Number of Road Accidents during - 2015'])
print("Mean of accidents happened in all states in year 2015 : {}".format(mean15))
# Out:
# Mean of accidents happened in all states in year 2015 : 13928.416666666666

# %%
mean16 = np.mean(df3['State/UT-Wise Total Number of Road Accidents during - 2016'])
print("Mean of accidents happened in all states in 2016 {}".format(mean16))
# Out:
# Mean of accidents happened in all states in 2016 13351.444444444445

# %%
df4 = pd.DataFrame([mean13])

# %%
labels = '2013', '2014', '2015', '2016'

# %%
total_mean = [mean13, mean14, mean15, mean16]

# %%
plt.bar(labels, total_mean)
plt.xticks(rotation = '60')
plt.title('Mean of State/UT-Wise Total Number of Road Accidents during')
# Out:
# Text(0.5, 1.0, 'Mean of State/UT-Wise Total Number of Road Accidents during')

# %%
plt.figure(figsize = (20,10))
plt.rcParams.update({'font.size':18})
y = df3['State/UT-Wise Total Number of Road Accidents during - 2013']
yd = df3['States/UTs']
p =df3['States/UTs'].nunique()
d = np.linspace(1,p,p)
plt.bar(d, y, align = 'center')
plt.xticks(d, yd, rotation = 90)
plt.xlabel('States')
plt.ylabel('Number of Accidents')
plt.title('Total number of Accidents in each State.')
plt.show()

# %% [markdown]
# # **DF 5 - ACCIDENTS DATA FRAME ACCORDING TO TIME OF DAY**

# %%
df5= pd.read_excel('/content/timeOfOccurence.xls')
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
df5.head()
# Out:
#   S. No.         States/Uts  ...  03-600hrs - (Night) - 2016  Total Accidents - 2016
# 0      1     Andhra Pradesh  ...                        1723                   24888
# 1      2  Arunachal Pradesh  ...                          27                     249
# 2      3              Assam  ...                         467                    7435
# 3      4              Bihar  ...                         882                    8222
# 4      5       Chhattisgarh  ...                         539                   13580
#
# [5 rows x 20 columns]

# %%
df5.drop('S. No.',axis = 1,inplace = True)
df5.set_index('States/Uts', inplace = True)
df5.drop('Total',axis =  0, inplace= True)

# %%
df5.head()
# Out:
#                    06-900hrs - Day - 2014  ...  Total Accidents - 2016
# States/Uts                                 ...
# Andhra Pradesh                       2548  ...                   24888
# Arunachal Pradesh                      43  ...                     249
# Assam                                1034  ...                    7435
# Bihar                                1433  ...                    8222
# Chhattisgarh                         1677  ...                   13580
#
# [5 rows x 18 columns]

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36 entries, Andhra Pradesh to Puducherry
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   06-900hrs - Day - 2014       36 non-null     int64
#  1   09-1200hrs - Day - 2014      36 non-null     int64
#  2   12-1500hrs - Day - 2014      36 non-null     int64
#  3   15-1800hrs - Day - 2014      36 non-null     int64
#  4   18-2100hrs - Night - 2014    36 non-null     int64
#  5   21-2400hrs - Night - 2014    36 non-null     int64
#  6   00-300hrs - Night - 2014     36 non-null     int64
#  7   03-600hrs - Night - 2014     36 non-null     int64
#  8   Total Accidents - 2014       36 non-null     int64
#  9   06-900hrs - (Day) - 2016     36 non-null     int64
#  10  09-1200hrs - (Day) - 2016    36 non-null     int64
#  11  12-1500hrs - (Day) - 2016    36 non-null     int64
#  12  15-1800hrs - (Day) - 2016    36 non-null     int64
# ...

# %%
df5.duplicated()
# Out:
# States/Uts
# Andhra Pradesh       False
# Arunachal Pradesh    False
# Assam                False
# Bihar                False
# Chhattisgarh         False
# Goa                  False
# Gujarat              False
# Haryana              False
# Himachal Pradesh     False
# Jammu & Kashmir      False
# Jharkhand            False
# Karnataka            False
# Kerala               False
# Madhya Pradesh       False
# Maharashtra          False
# Manipur              False
# Meghalaya            False
# Mizoram              False
# Nagaland             False
# Orissa               False
# Punjab               False
# Rajasthan            False
# Sikkim               False
# Tamil Nadu           False
# Telangana            False
# Tripura              False
# Uttarakhand          False
# Uttar Pradesh        False
# West Bengal          False
# A & N Islands        False
# Chandigarh           False
# D & N Haveli         False
# Daman & Diu          False
# Delhi                False
# ...

# %%
df5.nunique()
# Out:
# 06-900hrs - Day - 2014         36
# 09-1200hrs - Day - 2014        36
# 12-1500hrs - Day - 2014        36
# 15-1800hrs - Day - 2014        36
# 18-2100hrs - Night - 2014      35
# 21-2400hrs - Night - 2014      35
# 00-300hrs - Night - 2014       32
# 03-600hrs - Night - 2014       33
# Total Accidents - 2014         36
# 06-900hrs - (Day) - 2016       35
# 09-1200hrs - (Day) - 2016      36
# 12-1500hrs - (Day) - 2016      36
# 15-1800hrs - (Day) - 2016      35
# 18-2100hrs - (Night) - 2016    36
# 21-2400hrs - (Night) - 2016    35
# 00-300hrs - (Night) - 2016     33
# 03-600hrs - (Night) - 2016     33
# Total Accidents - 2016         35
# dtype: int64

# %%
plt.rcParams.update({'font.size'  : 18})
plt.figure(figsize = (20,10))

plt.plot(df5.index, df5['00-300hrs - Night - 2014'] ,label = '00-300hrs - Night - 2014')
plt.plot(df5['03-600hrs - Night - 2014'] ,label = '03-600hrs - Night - 2014')
plt.plot(df5['06-900hrs - Day - 2014'] ,label = '06-900hrs - Day - 2014')
plt.plot(df5['09-1200hrs - Day - 2014'] ,label = '09-1200hrs - Day - 2014')
plt.plot(df5['12-1500hrs - Day - 2014'] ,label = '12-1500hrs - Day - 2014')
plt.plot(df5['15-1800hrs - Day - 2014'] ,label = '15-1800hrs - Day - 2014')
plt.plot(df5['18-2100hrs - Night - 2014'] ,label = '18-2100hrs - Night - 2014')
plt.plot(df5['21-2400hrs - Night - 2014'] ,label = '21-2400hrs - Night - 2014')

plt.title("Line Chart showing accidents occuring as per time of occurence for each state for 2014.")
plt.xlabel("States/UTs")
plt.ylabel("Count of Accidents")
plt.xticks(rotation = 90)
plt.legend(loc = 'best')
plt.show()

# %% [markdown]
# # **Calculate accidents in day time and night time in 2014.**

# %%
dayTime2014 = df5['03-600hrs - Night - 2014'] + df5['06-900hrs - Day - 2014'] + \
              df5['09-1200hrs - Day - 2014'] + df5['12-1500hrs - Day - 2014'] + df5['15-1800hrs - Day - 2014']
nightTime2014 = df5['00-300hrs - Night - 2014'] + df5['18-2100hrs - Night - 2014' ] + df5['21-2400hrs - Night - 2014']

# %%
dayTime2014
# Out:
# States/Uts
# Andhra Pradesh       15362
# Arunachal Pradesh      147
# Assam                 5441
# Bihar                 6964
# Chhattisgarh          9416
# Goa                   2727
# Gujarat              15611
# Haryana               6714
# Himachal Pradesh      2076
# Jammu & Kashmir       4301
# Jharkhand             3896
# Karnataka            27881
# Kerala               25575
# Madhya Pradesh       38370
# Maharashtra          38763
# Manipur                509
# Meghalaya              270
# Mizoram                 81
# Nagaland               282
# Orissa                6450
# Punjab                4192
# Rajasthan            16417
# Sikkim                 145
# Tamil Nadu           43480
# Telangana            12597
# Tripura                498
# Uttarakhand           1002
# Uttar Pradesh        20517
# West Bengal           8795
# A & N Islands          150
# Chandigarh             201
# D & N Haveli            51
# Daman & Diu             22
# Delhi                 4801
# ...

# %%
nightTime2014
# Out:
# States/Uts
# Andhra Pradesh        9078
# Arunachal Pradesh       58
# Assam                 1703
# Bihar                 2592
# Chhattisgarh          4405
# Goa                   1502
# Gujarat               8101
# Haryana               3962
# Himachal Pradesh       982
# Jammu & Kashmir       1560
# Jharkhand             1305
# Karnataka            15832
# Kerala               10707
# Madhya Pradesh       15102
# Maharashtra          22864
# Manipur                234
# Meghalaya              272
# Mizoram                 51
# Nagaland                23
# Orissa                3198
# Punjab                2199
# Rajasthan             8211
# Sikkim                  58
# Tamil Nadu           23770
# Telangana             7481
# Tripura                218
# Uttarakhand            408
# Uttar Pradesh        10517
# West Bengal           4080
# A & N Islands           68
# Chandigarh             168
# D & N Haveli            36
# Daman & Diu             17
# Delhi                 3822
# ...

# %%
plt.rcParams.update({'font.size'  : 18})
fig = plt.figure(figsize = (20,10))

ax = fig.add_axes([0,0,1,1])

ax.bar(df5.index, dayTime2014, label = 'Day Time')
ax.bar(df5.index,nightTime2014, label = 'Night Time')

plt.title("Line chart showing flow of number of accidents happening at DAY TIME and NIGHT TIME for 2014.")
plt.xlabel("States/UTs")
plt.ylabel("Count of Accidents")
plt.xticks(rotation = 90)
plt.legend( loc = 'best')
plt.show()

# %% [markdown]
# # **Total day and night time accidents in 2014 and 2016**

# %%
dayTime2016 = df5['03-600hrs - (Night) - 2016'] + df5['06-900hrs - (Day) - 2016'] + \
              df5['09-1200hrs - (Day) - 2016'] + df5['12-1500hrs - (Day) - 2016'] + df5['15-1800hrs - (Day) - 2016']
nightTime2016 = df5['00-300hrs - (Night) - 2016'] + df5['18-2100hrs - (Night) - 2016'] + df5['21-2400hrs - (Night) - 2016']

# %%
dayTime2014
# Out:
# States/Uts
# Andhra Pradesh       15362
# Arunachal Pradesh      147
# Assam                 5441
# Bihar                 6964
# Chhattisgarh          9416
# Goa                   2727
# Gujarat              15611
# Haryana               6714
# Himachal Pradesh      2076
# Jammu & Kashmir       4301
# Jharkhand             3896
# Karnataka            27881
# Kerala               25575
# Madhya Pradesh       38370
# Maharashtra          38763
# Manipur                509
# Meghalaya              270
# Mizoram                 81
# Nagaland               282
# Orissa                6450
# Punjab                4192
# Rajasthan            16417
# Sikkim                 145
# Tamil Nadu           43480
# Telangana            12597
# Tripura                498
# Uttarakhand           1002
# Uttar Pradesh        20517
# West Bengal           8795
# A & N Islands          150
# Chandigarh             201
# D & N Haveli            51
# Daman & Diu             22
# Delhi                 4801
# ...

# %%
dayTime2016
# Out:
# States/Uts
# Andhra Pradesh       15911
# Arunachal Pradesh      185
# Assam                 5260
# Bihar                 5994
# Chhattisgarh          9062
# Goa                   2755
# Gujarat              14017
# Haryana               7023
# Himachal Pradesh      1994
# Jammu & Kashmir       4202
# Jharkhand             3349
# Karnataka            29634
# Kerala               28356
# Madhya Pradesh       36103
# Maharashtra          24732
# Manipur                340
# Meghalaya              357
# Mizoram                 63
# Nagaland                56
# Orissa                7031
# Punjab                4420
# Rajasthan            15705
# Sikkim                 165
# Tamil Nadu           45948
# Telangana            14199
# Tripura                393
# Uttarakhand           1120
# Uttar Pradesh        24153
# West Bengal          10839
# A & N Islands          173
# Chandigarh             243
# D & N Haveli            39
# Daman & Diu             34
# Delhi                 4243
# ...

# %%
dayTimeTotal =  dayTime2014 + dayTime2016

# %%
fig = plt.figure(figsize = (20,10))

ax = fig.add_axes([0,0,1,1])
UT = np.arange(36)

ax.bar(UT,dayTime2014, width = 0.2, label = 'Day Time 2014')
ax.bar(UT+0.2,dayTime2016, width = 0.2,label = 'Day Time 2016')

plt.title("Line chart showing flow of number of accidents happening at DAY TIME and NIGHT TIME for 2014.")
plt.xlabel("States/UTs")
plt.ylabel("Count of Accidents")
plt.xticks(UT, df5.index,rotation = 90)
plt.legend( loc = 'best')
plt.show()

# %%
dayTimeTotal.head()
# Out:
# States/Uts
# Andhra Pradesh       31273
# Arunachal Pradesh      332
# Assam                10701
# Bihar                12958
# Chhattisgarh         18478
# dtype: int64

# %%
nightTimeTotal = nightTime2014 + nightTime2016
nightTimeTotal.head()
# Out:
# States/Uts
# Andhra Pradesh       18055
# Arunachal Pradesh      122
# Assam                 3878
# Bihar                 4820
# Chhattisgarh          8923
# dtype: int64

# %%
df5.index
# Out:
# Index(['Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar', 'Chhattisgarh',
#        'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra',
#        'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Orissa', 'Punjab',
#        'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura',
#        'Uttarakhand', 'Uttar Pradesh', 'West Bengal', 'A & N Islands',
#        'Chandigarh', 'D & N Haveli', 'Daman & Diu', 'Delhi', 'Lakshadweep',
#        'Puducherry'],
#       dtype='object', name='States/Uts')

# %%
plt.rcParams.update({'font.size'  : 18})
plt.figure(figsize = (20,10))

UT = np.arange(36)

plt.bar(UT, nightTimeTotal, width = 0.2, label = 'Night Time Total 2014-2016')
plt.bar(UT+0.2, dayTimeTotal, width = 0.2, label = 'Day Time Total 2014-2016')

plt.xlabel("States")
plt.ylabel("Accidents")
plt.legend(loc = 'best')
plt.title("Number of Accidents happening in DAY and NIGHT TIME for 2014, 2016.")
plt.xticks(UT, df5.index, rotation=90)
plt.show()

# %% [markdown]
# # **DF6**

# %%
df6 = pd.read_csv('/content/Details_of_road_accident_deaths_by_situation_state_2014.csv')

# %%
df6
# Out:
#              States/UTs  Year  ... Victims Died_Transgender  Victims Died_Total
# 0        Andhra Pradesh  2014  ...                        0                1006
# 1        Andhra Pradesh  2014  ...                        0                 678
# 2        Andhra Pradesh  2014  ...                        0                  25
# 3        Andhra Pradesh  2014  ...                        0                 117
# 4        Andhra Pradesh  2014  ...                        0                 186
# ...                 ...   ...  ...                      ...                 ...
# 1438  Total (All India)  2014  ...                        0                  73
# 1439  Total (All India)  2014  ...                        2                5943
# 1440  Total (All India)  2014  ...                        0                3419
# 1441  Total (All India)  2014  ...                        2               10407
# 1442  Total (All India)  2014  ...                       17              107274
#
# ...

# %%
df6.dtypes
# Out:
# States/UTs                                        object
# Year                                               int64
# CrimeHead                                         object
# Offenders (Driver/Pedestrian) Died_Male            int64
# Offenders (Driver/Pedestrian) Died_Female          int64
# Offenders (Driver/Pedestrian) Died_Transgender     int64
# Offenders (Driver/Pedestrian) Died_Total           int64
# Victims Died_Male                                  int64
# Victims Died_Female                                int64
# Victims Died_Transgender                           int64
# Victims Died_Total                                 int64
# dtype: object

# %% [markdown]
# # **Offender who died according to gender.**

# %%
meanOffenderMale = (np.mean(df6['Offenders (Driver/Pedestrian) Died_Male']))
meanOffenderMale
# Out:
# 251.59251559251558

# %%
meanOffenderFemale = (np.mean(df6['Offenders (Driver/Pedestrian) Died_Female']))
meanOffenderFemale
# Out:
# 21.717255717255718

# %%
meanOffenderTrans = (np.mean(df6['Offenders (Driver/Pedestrian) Died_Transgender']))
meanOffenderTrans
# Out:
# 0.0

# %%
sizes = [meanOffenderMale, meanOffenderFemale, meanOffenderTrans]
labels = ['Died Male','Died Female', 'Died Trans']
explode = (0, 0.1, 0)
plt.pie(sizes, labels = labels, explode = explode, autopct = '%.1f%%')
plt.title("Percentage of offenders who died according to gender.")
plt.show()

# %% [markdown]
# # **Victims who died according to gender.**

# %%
meanVictMale = (np.mean(df6['Victims Died_Male']))

# %%
meanVictFemale = (np.mean(df6['Victims Died_Female']))

# %%
meanVictTrans = (np.mean(df6['Victims Died_Transgender']))
meanVictMale, meanVictFemale, meanVictTrans
# Out:
# (705.8731808731809, 138.59667359667358, 0.13513513513513514)

# %%
sizes = [meanVictMale, meanVictFemale, meanVictTrans]
labels = 'Victims Died_Male', 'Victims Died_Female', 'Victims Died_Transgender'
explode =(0, 0.1, 0)

plt.pie(sizes, labels = labels, explode = explode, autopct = '%.4f%%')
plt.title("Percentage of Victims according to Gender who died.")
plt.show()

# %% [markdown]
# # **Ratio of Offender vs Victim**

# %%
totalOffenderDied = meanOffenderMale + meanOffenderFemale + meanOffenderTrans

# %%
totalVictDied = meanVictMale + meanVictFemale + meanVictTrans

# %%
sizes = [totalOffenderDied, totalVictDied]
labels = 'Offender', 'Victims'
explode =(0, 0.1)

plt.pie(sizes, labels = labels, explode = explode, autopct = '%.4f%%')
plt.title("Percentage of Offender Vs Victim who died.")
plt.show()

# %% [markdown]
# # **Driver's License**

# %%
license_data = pd.read_excel('license.xls')
license_data = license_data.drop(['Licence not known'], axis=1)

# %%
license_data.drop(36, axis = 0, inplace =True)

# %%
license_data.head()
# Out:
#           States/UTs  ...  Without Licence
# 0     Andhra Pradesh  ...             3686
# 1  Arunachal Pradesh  ...               56
# 2              Assam  ...              453
# 3              Bihar  ...              425
# 4       Chhattisgarh  ...             2285
#
# [5 rows x 4 columns]

# %%
fig = plt.figure(figsize = (10,3))
ax = fig.add_axes([0, 0, 1, 1])
labels = license_data.columns.values[1:]
condition = [license_data['Valid Permanent License'].sum(), license_data['Learner\'s Licence'].sum(), license_data['Without Licence'].sum()]
plt.ylabel('Number of accidents')
plt.xlabel('Driver\'s License Level')
plt.title('Number of accidents vs Driver\'s license')
#plt.xticks(rotation = 90)
ax.bar(labels,condition)
plt.show()

# %% [markdown]
# Observation:
#
# * Expectedly, most accidents are seen by Valid permanent license holders because of their majority. However, it is interesting to see that there are more drivers who met with an accident without a license than with a learner's license

# %% [markdown]
# # **Weather Conditions**

# %%
weather_condition = pd.read_excel('climate.xls', usecols=['Sunny/Clear - Total Accidents', 'Rainy - Total Accidents', 'Foggy & Misty - Total Accidents', 'Hail/Sleet - Total Accidents', 'Others - Total Accidents'])

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
labels = ['Sunny', 'Rainy', 'Foggy', 'Hail', 'Others']
condition = [weather_condition['Sunny/Clear - Total Accidents'].values[-1], weather_condition['Rainy - Total Accidents'].values[-1], weather_condition['Foggy & Misty - Total Accidents'].values[-1], weather_condition['Hail/Sleet - Total Accidents'].values[-1], weather_condition['Others - Total Accidents'].values[-1]]
plt.ylabel('Number of accidents')
plt.title('Number of accidents vs Weather condition')
plt.xlabel('Weather condition')
ax.bar(labels,condition)
plt.show()

# %% [markdown]
# # **Road Condition**

# %%
road_conditions = pd.read_excel('road_environment.xls', usecols=['Residential Area - Total Accidents', 'Institutional Area - Total Accidents', 'Market/Commercial area - Total Accidents', 'Open Area - Total Accidents', 'Others - Total Accidents'])

# %%
fig = plt.figure(figsize = (10,5))
ax = fig.add_axes([0, 0, 1, 1])
labels = ['Residential', 'Instituional', 'Commercial', 'Open', 'Other']
condition = [road_conditions['Residential Area - Total Accidents'].values[-1], road_conditions['Institutional Area - Total Accidents'].values[-1], road_conditions['Market/Commercial area - Total Accidents'].values[-1], road_conditions['Open Area - Total Accidents'].values[-1], road_conditions['Others - Total Accidents'].values[-1]]
plt.ylabel('Number of accidents')
plt.title('Number of accidents vs Road conditions')
plt.xlabel('Road Condition')
ax.bar(labels,condition)
plt.show()

# %% [markdown]
# Observation:
# *   We observe that open roads witness more number of accidents than road conditions.

# %% [markdown]
# # **Accidents involving non wearing of safety gear i.e helmet or seat-belt**

# %%
safety_equip = pd.read_excel('no_safety.xls')

# %%
safety_equip.head()
# Out:
#           States/UTs  ...  Passengers - Non Injured - No
# 0     Andhra Pradesh  ...                           1877
# 1  Arunachal Pradesh  ...                              0
# 2              Assam  ...                              0
# 3              Bihar  ...                              0
# 4       Chhattisgarh  ...                              1
#
# [5 rows x 17 columns]

# %%
sizes = [safety_equip['Drivers - Persons Killed - Yes'].values[-1], safety_equip['Passengers - Persons Killed - Yes'].values[-1]]
labels = 'Driver', 'Passenger'
explode =(0, 0.1)

plt.pie(sizes, labels = labels, explode = explode, autopct = '%.2f%%')
plt.title("Driver Vs Passenger who died due to non wearing of safety of gear")
plt.show()

# %%
sizes = [safety_equip['Drivers - Persons Killed - No'].values[-1], safety_equip['Passengers - Persons Killed - No'].values[-1]]
labels = 'Driver', 'Passenger'
explode =(0, 0.1)

plt.pie(sizes, labels = labels, explode = explode, autopct = '%.2f%%')
plt.title("Driver Vs Passenger who survived due to non wearing of safety of gear")
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
labels = ['Killed', 'Not Killed']
drivers = [safety_equip['Drivers - Persons Killed - Yes'].values[-1], safety_equip['Drivers - Persons Killed - No'].values[-1]]
plt.ylabel('Number of cases')
plt.xlabel('Status')
plt.title('Drivers WITHOUT safety equipment (helmet/belt)')
ax.bar(labels,drivers)
plt.show()

# %% [markdown]
# # **Season wise Accidents**

# %%
state_month=pd.read_csv('accidents_month_wise.csv')

# %%
state_month.head()
# Out:
#         STATE/UT  YEAR  JANUARY  FEBRUARY  ...  OCTOBER  NOVEMBER  DECEMBER  TOTAL
# 0  A & N Islands  2001        8        23  ...       12        13        22    181
# 1  A & N Islands  2002       12        10  ...       21        11        17    168
# 2  A & N Islands  2003       19        13  ...       25        14        15    180
# 3  A & N Islands  2004       21        14  ...       20        15        24    215
# 4  A & N Islands  2005       19        21  ...       19        10        16    206
#
# [5 rows x 15 columns]

# %%
state_month['SUMMER']=state_month[['JUNE','JULY','AUGUST']].sum(axis=1)
state_month['AUTUMN']=state_month[['SEPTEMBER','OCTOBER','NOVEMBER']].sum(axis=1)
state_month['WINTER']=state_month[['DECEMBER','JANUARY','FEBRUARY']].sum(axis=1)
state_month['SPRING']=state_month[['MARCH','APRIL','MAY']].sum(axis=1)

# %%
state_month.head()
# Out:
#         STATE/UT  YEAR  JANUARY  FEBRUARY  ...  SUMMER  AUTUMN  WINTER  SPRING
# 0  A & N Islands  2001        8        23  ...      52      32      53      44
# 1  A & N Islands  2002       12        10  ...      34      55      39      40
# 2  A & N Islands  2003       19        13  ...      36      56      47      41
# 3  A & N Islands  2004       21        14  ...      53      51      59      52
# 4  A & N Islands  2005       19        21  ...      54      44      56      52
#
# [5 rows x 19 columns]

# %%
state_month=state_month.drop(['YEAR','JANUARY','FEBRUARY','MARCH','APRIL','MAY','JUNE','JULY'
                                             ,'AUGUST','SEPTEMBER','OCTOBER','NOVEMBER','DECEMBER'], axis=1)

# %%
state_month.head()
# Out:
#         STATE/UT  TOTAL  SUMMER  AUTUMN  WINTER  SPRING
# 0  A & N Islands    181      52      32      53      44
# 1  A & N Islands    168      34      55      39      40
# 2  A & N Islands    180      36      56      47      41
# 3  A & N Islands    215      53      51      59      52
# 4  A & N Islands    206      54      44      56      52

# %%
state_grouped=state_month.groupby(['STATE/UT']).sum()

# %%
state_grouped['%_SUMMER']=state_grouped['SUMMER']/state_grouped['TOTAL']
state_grouped['%_AUTUMN']=state_grouped['AUTUMN']/state_grouped['TOTAL']
state_grouped['%_WINTER']=state_grouped['WINTER']/state_grouped['TOTAL']
state_grouped['%_SPRING']=state_grouped['SPRING']/state_grouped['TOTAL']

# %%
state_grouped.head()
# Out:
#                     TOTAL  SUMMER  AUTUMN  ...  %_AUTUMN  %_WINTER  %_SPRING
# STATE/UT                                   ...
# A & N Islands        2893     689     710  ...  0.245420  0.269271  0.247148
# Andhra Pradesh     546821  132891  129230  ...  0.236330  0.253525  0.267120
# Arunachal Pradesh    3389     748     875  ...  0.258188  0.271467  0.249631
# Assam               61718   14696   15382  ...  0.249230  0.253913  0.258741
# Bihar               92648   23506   20866  ...  0.225218  0.237393  0.283676
#
# [5 rows x 9 columns]

# %%
plt.figure(figsize= (10,5))
state_grouped.boxplot(['%_SUMMER','%_WINTER','%_AUTUMN','%_SPRING'])
plt.show()

# %%
plt.figure(figsize=(15,15))
plt.rcParams.update({'font.size':11})

plt.subplots_adjust(wspace=0.4, hspace=0.4)

ax1 = plt.subplot(2,2,1)
summer_sorted=state_grouped.sort_values('%_SUMMER')
summer_sorted['%_SUMMER'].tail(5).plot.bar(title='Highest Summer Accidents percent in total accidents',color='b')

ax2 = plt.subplot(2,2,2)
winter_sorted=state_grouped.sort_values('%_WINTER')
winter_sorted['%_WINTER'].tail(5).plot.bar(title='Highest Winter Accidents percent in total accidents',color='g')

ax3 = plt.subplot(2,2,3)
autumn_sorted=state_grouped.sort_values('%_AUTUMN')
autumn_sorted['%_AUTUMN'].tail(5).plot.bar(title='Highest Autumn Accidents percent in total accidents',color='r')

ax4 = plt.subplot(2,2,4)
spring_sorted=state_grouped.sort_values('%_SPRING')
spring_sorted['%_SPRING'].tail(5).plot.bar(title='Highest Spring Accidents percent in total accidents',color='black')

# %% [markdown]
# # **df7** - Type of Vehicles.
# # This dataset tells about the number of accidents happening along different types of vehicles.

# %%
df7 = pd.read_csv('/content/typeOfVehicle.csv')
df7.head()
# Out:
#   Sl. No.  ... Population
# 0       1  ...   52410653
# 1       2  ...    1383727
# 2       3  ...   31205576
# 3       4  ...  104099452
# 4       5  ...   25545198
#
# [5 rows x 59 columns]

# %%
df7.drop(36, axis = 0,inplace = True)

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36 entries, 0 to 35
# Data columns (total 59 columns):
#  #   Column                                                                                Non-Null Count  Dtype
# ---  ------                                                                                --------------  -----
#  0   Sl. No.                                                                               36 non-null     object
#  1   States/UTs                                                                            36 non-null     object
#  2   Two-Wheelers - Number of Road Accidents - Fatal - 2014                                36 non-null     int64
#  3   Two-Wheelers - Number of Road Accidents - Fatal - 2014 per 1L people                  36 non-null     float64
#  4   Two-Wheelers - Number of Road Accidents - Total - 2014                                36 non-null     int64
# ...

# %%
df7.dropna(axis = 0, how = 'any', inplace = True)

# %%
Auto_Rickshaw = df7['Auto-Rickshaws - Number of Road Accidents - Total - 2014'].sum()
Two_Wheeler = df7['Two-Wheelers - Number of Road Accidents - Total - 2014'].sum()
Car = df7['Cars, Jeeps,Taxis - Number of Road Accidents - Total - 2014'].sum()
Bus = df7['Buses - Number of Road Accidents - Total - 2014'].sum()
Trucks = df7['Trucks, Tempos,MAVs,Tractors - Number of Road Accidents - Total - 2014'].sum()
Other_Motor_Vehicle = df7['Other Motor Vehicles - Number of Road Accidents - Total - 2014'].sum()
Other_Objects = df7['Other Vehicles/Objects - Number of Road Accidents - Total - 2014'].sum()

# %%
sizes = [Auto_Rickshaw, Two_Wheeler, Car, Bus, Trucks, Other_Motor_Vehicle, Other_Objects]
labels = ['Auto_Rickshaw', 'Two_Wheeler', 'Car', 'Bus', 'Trucks', 'Other_Motor_Vehicle', 'Other_Objects']

plt.pie(sizes, labels = labels, autopct = '%.2f%%')
plt.title("Percentage of Vehicle Type involved in accidents.")
plt.show()

# %% [markdown]
# **Total Accidents by types of vehicles in every state**

# %%
plt.figure(figsize=(20,10))
plt.rcParams.update({'font.size':18})
UT=np.arange(36)
UT=UT*2

plt.bar(UT-0.6,df7['Two-Wheelers - Number of Road Accidents - Total - 2014'],width=0.2,color='r',align='center',label='Two-Wheelers')
plt.bar(UT-0.4,df7['Auto-Rickshaws - Number of Road Accidents - Total - 2014'],width=0.2,color='black',align='center',label='Auto-Rickshaws')
plt.bar(UT-0.2,df7['Cars, Jeeps,Taxis - Number of Road Accidents - Total - 2014'],width=0.2,color='g',align='center',label='Cars,Jeeps,Taxis')
plt.bar(UT,df7['Buses - Number of Road Accidents - Total - 2014'],width=0.2,color='b',align='center',label='Buses')
plt.bar(UT+0.2,df7['Trucks, Tempos,MAVs,Tractors - Number of Road Accidents - Total - 2014'],width=0.2,color='yellow',align='center',label='Trucks, Tempos,MAVs,Tractors')
plt.bar(UT+0.4,df7['Other Motor Vehicles - Number of Road Accidents - Total - 2014'],width=0.2,color='brown',align='center',label='Other Motor Vehicles')
plt.bar(UT+0.6,df7['Other Vehicles/Objects - Number of Road Accidents - Total - 2014'],width=0.2,color='purple',align='center',label='Other Vehicles/Objects')

plt.xticks(UT,df7['States/UTs'],rotation='vertical')
plt.legend(loc="best")
plt.title("Number of Total Accidents for each vehicle of that state")
plt.show()

# %% [markdown]
# # **Number of Persons Injured for each vehicle type per 1L people of that state**

# %%
plt.figure(figsize=(20,10))
plt.rcParams.update({'font.size':18})

plt.bar(UT-0.6,df7['Two-Wheelers - Number of Persons - Injured - 2014 per 1L people'],width=0.2,color='r',align='center',label='Two-Wheelers')
plt.bar(UT-0.4,df7['Auto-Rickshaws - Number of Persons - Injured - 2014 per 1L people'],width=0.2,color='black',align='center',label='Auto-Rickshaws')
plt.bar(UT-0.2,df7['Cars, Jeeps,Taxis - Number of Persons - Injured - 2014 per 1L people'],width=0.2,color='g',align='center',label='Cars,Jeeps,Taxis')
plt.bar(UT,df7['Buses - Number of Persons - Injured - 2014 per 1L people'],width=0.2,color='b',align='center',label='Buses')
plt.bar(UT+0.2,df7['Trucks, Tempos,MAVs,Tractors - Number of Persons - Injured - 2014 per 1L people'],width=0.2,color='yellow',align='center',label='Trucks, Tempos,MAVs,Tractors')
plt.bar(UT+0.4,df7['Other Motor Vehicles - Number of Persons - Injured - 2014 per 1L people'],width=0.2,color='brown',align='center',label='Other Motor Vehicles')
plt.bar(UT+0.6,df7['Other Vehicles/Objects - Number of Persons - Injured - 2014 per 1L people'],width=0.2,color='purple',align='center',label='Other Vehicles/Objects')

plt.xticks(UT,df7['States/UTs'],rotation='vertical')
plt.legend(loc='upper left')
plt.title("Number of Persons Injured for each vehicle type per 1L people of that state")
plt.show()

# %% [markdown]
# # **Data for 2  Wheelers**

# %%
plt.figure(figsize=(20,10))
plt.rcParams.update({'font.size':18})
UT=np.arange(36)

plt.bar(UT-0.4,df7['Two-Wheelers - Number of Persons - Injured - 2014 per 1L people'],width=0.2,color='r',align='center',label='Injured')
plt.bar(UT-0.2,df7['Two-Wheelers - Number of Persons - Killed - 2014 per 1L people'],width=0.2,color='g',align='center',label='Killed')
plt.bar(UT,df7['Two-Wheelers - Number of Road Accidents - Total - 2014 per 1L people'],width=0.2,color='b',align='center',label='Total Accidents')
plt.bar(UT+0.2,df7['Two-Wheelers - Number of Road Accidents - Fatal - 2014 per 1L people'],width=0.2,color='yellow',align='center',label='Fatal Accidents')

plt.xticks(UT,df7['States/UTs'],rotation='vertical')
plt.legend(loc="best")
plt.title("Number of Persons Injured, Killed; Road Accidents Total and fatal for 2 wheelers per 1L people of that state")
plt.show()

# %% [markdown]
# # **Data for Car , Jeeps and Taxis**

# %%
plt.figure(figsize=(20,10))
plt.rcParams.update({'font.size':18})

plt.bar(UT-0.4,df7['Cars, Jeeps,Taxis - Number of Persons - Injured - 2014 per 1L people'],width=0.2,color='r',align='center',label='Injured')
plt.bar(UT-0.2,df7['Cars, Jeeps,Taxis - Number of Persons - Killed - 2014 per 1L people'],width=0.2,color='g',align='center',label='Killed')
plt.bar(UT,df7['Cars, Jeeps,Taxis - Number of Road Accidents - Total - 2014 per 1L people'],width=0.2,color='b',align='center',label='Total Accidents')
plt.bar(UT+0.2,df7['Cars, Jeeps,Taxis - Number of Road Accidents - Fatal - 2014 per 1L people'],width=0.2,color='yellow',align='center',label='Fatal Accidents')

plt.xticks(UT,df7['States/UTs'],rotation='vertical')
plt.legend(loc="best")
plt.title("Number of Persons Injured, Killed; Road Accidents Total and fatal for Cars, Jeeps and Taxis per 1L people of that state")
plt.show()

# %% [markdown]
# # **Data for Buses**

# %%
plt.figure(figsize=(20,10))
plt.rcParams.update({'font.size':18})

plt.bar(UT-0.4,df7['Buses - Number of Persons - Injured - 2014 per 1L people'],width=0.2,color='r',align='center',label='Injured')
plt.bar(UT-0.2,df7['Buses - Number of Persons - Killed - 2014 per 1L people'],width=0.2,color='g',align='center',label='Killed')
plt.bar(UT,df7['Buses - Number of Road Accidents - Total - 2014 per 1L people'],width=0.2,color='b',align='center',label='Total Accidents')
plt.bar(UT+0.2,df7['Buses - Number of Road Accidents - Fatal - 2014 per 1L people'],width=0.2,color='yellow',align='center',label='Fatal Accidents')

plt.xticks(UT,df7['States/UTs'],rotation='vertical')
plt.legend(loc="best")
plt.title("Number of Persons Injured, Killed; Road Accidents Total and fatal by Buses per 1L people of that state")
plt.show()

# %% [markdown]
# # **Data for Trucks**

# %%
plt.figure(figsize=(20,10))
plt.rcParams.update({'font.size':18})

plt.bar(UT-0.4,df7['Trucks, Tempos,MAVs,Tractors - Number of Persons - Injured - 2014 per 1L people'],width=0.2,color='r',align='center',label='Injured')
plt.bar(UT-0.2,df7['Trucks, Tempos,MAVs,Tractors - Number of Persons - Killed - 2014 per 1L people'],width=0.2,color='g',align='center',label='Killed')
plt.bar(UT,df7['Trucks, Tempos,MAVs,Tractors - Number of Road Accidents - Total - 2014 per 1L people'],width=0.2,color='b',align='center',label='Total Accidents')
plt.bar(UT+0.2,df7['Trucks, Tempos,MAVs,Tractors - Number of Road Accidents - Fatal - 2014 per 1L people'],width=0.2,color='yellow',align='center',label='Fatal Accidents')

plt.xticks(UT,df7['States/UTs'],rotation='vertical')
plt.legend(loc="best")
plt.title("Number of Persons Injured, Killed; Road Accidents Total and fatal by Trucks and Tractors per 1L people of that state")
plt.show()
